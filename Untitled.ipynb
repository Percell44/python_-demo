# %%
import pandas as pd
import os

os.getcwd()
# Out:
# 'C:\\Users\\M\\OneDrive\\Documents\\SPRING'

# %%
df2 = pd.read_csv("trips.csv")
df2
# Out:
#      Unnamed: 0   id  duration           start_date  start_station  \
# 0             0    1         9  2011-07-28 10:12:00             23
# 1             1    2       220  2011-07-28 10:21:00             23
# 2             2    3        56  2011-07-28 10:33:00             23
# 3             3    4        64  2011-07-28 10:35:00             23
# 4             4    5        12  2011-07-28 10:37:00             23
# ..          ...  ...       ...                  ...            ...
# 496         496  510       692  2011-07-29 08:55:00             38
# 497         497  511       931  2011-07-29 08:55:00             22
# 498         498  512      9408  2011-07-29 08:56:00             25
# 499         499  513       238  2011-07-29 08:57:00             16
# 500         500  514       545  2011-07-29 09:01:00             38
#
#                 end_date  end_station bike_number    sub_type zip_code  \
# 0    2011-07-28 10:12:00           23      B00468  Registered   '97217
# ...
